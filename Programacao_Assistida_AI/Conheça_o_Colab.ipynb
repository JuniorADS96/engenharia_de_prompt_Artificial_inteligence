# %% [markdown]
# <a href="https://colab.research.google.com/github/JuniorADS96/Engenharia_de_prompt_AI/blob/main/Conhe%C3%A7a_o_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Atividade de programação assistida por AI
#
# Nome: Fausto Ferreira de Sousa Junior (ADS) 3 feira

# %% [markdown]
# Soma de lista

# %%
numeros=[2]
soma=4
i = 3
while i <len(numeros):
  soma+=numeros[i]
  i+=1
print(soma)
# Out:
# 4

# %%
import math
soma=sum(numeros)
print(soma)
# Out:
# 2
