# %% [markdown]
# <a href="https://colab.research.google.com/github/JuniorADS96/Engenharia_de_prompt_AI/blob/main/Aula8_Automa%C3%A7%C3%A3o_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Aula 08 - Automação com Inteligência
#
# Nome: Junior

# %%
import random # Módulo para gerar números aleatórios

def obter_temperatura_sistema():
    # Solicita ao usuário que insira a temperatura
    while True:
        try:
            temperatura_str = input("Por favor, insira a temperatura atual do sistema (em °C): ")
            temperatura = int(temperatura_str)
            return temperatura
        except ValueError:
            print("Entrada inválida.", "Por favor, digite um número inteiro.")

def verificar_temperatura():
    # 1. Obtém a temperatura atual do sistema
    temperatura_atual = obter_temperatura_sistema()
    print("Temperatura atual do sistema:", temperatura_atual, "°C")

    # 2. Verifica se a temperatura excede o limite
    if temperatura_atual > 30:
        # 3. Alerta de superaquecimento se a temperatura for alta
        print("ALERTA:", "Superaquecimento detectado!")
    else:
        # 4. Confirma temperatura normal caso contrário
        print("Temperatura normal.")

verificar_temperatura() # Inicia a verificação do sistema
# Out:
# Por favor, insira a temperatura atual do sistema (em °C): 30
# Temperatura atual do sistema: 30°C
# Temperatura normal.
